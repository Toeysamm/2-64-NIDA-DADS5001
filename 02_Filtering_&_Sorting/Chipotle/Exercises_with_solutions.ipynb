# %% [markdown]
# # Ex1 - Filtering and Sorting Data
#
# Check out [Chipotle Exercises Video Tutorial](https://youtu.be/ZZPiWZpdekA) to watch a data scientist go through the exercises

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
pd.options.display.max_columns=20 #ต้องการให้แสดงค่าทุก columns จุ้ยแนะนำอ.มา

# %% [markdown]
# ### Step 2. Import the dataset from this [URL](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')    #read csv --> file csv normally is sep = ','  , but this url is tab so use sep = '\t'

chipo.head() # ดูข้อมูล 5 อันดับแรก
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.info() #.info  เพื่อดู summary ทั้งหมดของ type chipo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Step 4. How many items price more than $10.00?

# %%
#ต้องการคำนวณหา ค่า price แต่มันมีอักษรพิเศษ $ อยู่ จึงต้องการตัดออก 
#และจาก chipo.info จะเห็นว่า item_price ไม่ใช่ int แต่เป็น obj จึงไม่สามารถหา max min ได้

# clean the item_price column and transform it in a float

#toey test
#prices_lst = []
#for value in chipo.item_price :
  #print(value)
  #prices = float(value[1:-1]) # เอาค่า index ตัวที่ 1 ถึงตัวสุดท้าย (ไม่เอาตัวที่ 0 ที่เป็น $) กำหนดให้เป็นค่า float
  #print(prices)
  #prices_lst.append(prices)
#prices_lst

# reassign the column with the cleaned prices
#chipo.item_price = prices_lst 
#print(chipo.head()) # show 5th

# %%
# clean the item_price column and transform it in a float
#teacher test
prices = [float(value[1:-1]) for value in chipo.item_price]
#print(prices)

# reassign the column with the cleaned prices
chipo.item_price = prices 
#print(chipo.head()) # show 5th

#chipo.query("item_price > 10") #ใช้ query ใน pandas ช่วยในการ filter ได้เลย
#chipo.query("item_price > 10").item_name #ใช้ query ใน pandas ช่วยในการ filter ได้เลย ต้องการ item_name (item_name แสดงซ้ำกัน)
#chipo.query("item_price > 10").item_name.unique() #ใช้ query ใน pandas ช่วยในการ filter ได้เลย ต้องการ item_name (item_name แสดงไม่ซ้ำกัน)
chipo.query("item_price > 10").item_name.nunique() #ใช้ query ใน pandas ช่วยในการ filter ได้เลย ต้องการให้นับจำนวน item_name (item_name แสดงไม่ซ้ำกัน)
#item_price ที่มากกว่า 10
# Out:
# 31

# %% [markdown]
# ### Step 4. Sort by the name of the item

# %%
#chipo.item_name.sort_values()

# OR

chipo.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...                                                 ...         ...
# 2384  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 781   [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...        8.75
# 2851  [Roasted Chili Corn Salsa (Medium), [Black Bea...        8.49
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...        8.49
#
# [4622 rows x 5 columns]

# %% [markdown]
# ###Step 5. What is the price of each item?

# %% [markdown]
# print a data frame with only two columns item_name and item_price

# %%
# delete the duplicates in item_name and quantity
chipo_filtered = chipo.drop_duplicates(['item_name','quantity']) #Filter item_name โดยตัดตัวที่ซ้ำกันใน quantity ออก
#print(chipo_filtered.head())

# select only the products with quantity equals to 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
#print(chipo_one_prod)

# select only the item_name and item_price colums
price_per_item = chipo_one_prod[['item_name','item_price']]
#print(price_per_item)

# sort the value from the most to less expensive
price_per_item.sort_values(by = 'item_price', ascending= False).head(20)
# Out:
#                   item_name  item_price
# 606        Steak Salad Bowl       11.89
# 1229    Barbacoa Salad Bowl       11.89
# 1132    Carnitas Salad Bowl       11.89
# 7             Steak Burrito       11.75
# 168   Barbacoa Crispy Tacos       11.75
# 39            Barbacoa Bowl       11.75
# 738       Veggie Soft Tacos       11.25
# 186       Veggie Salad Bowl       11.25
# 62              Veggie Bowl       11.25
# 57           Veggie Burrito       11.25
# 250           Chicken Salad       10.98
# 5              Chicken Bowl       10.98
# 8          Steak Soft Tacos        9.25
# 554   Carnitas Crispy Tacos        9.25
# 237     Carnitas Soft Tacos        9.25
# 56      Barbacoa Soft Tacos        9.25
# 92       Steak Crispy Tacos        9.25
# 664             Steak Salad        8.99
# 54               Steak Bowl        8.99
# 3750         Carnitas Salad        8.99

# %% [markdown]
# ### Step 5. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ###Step 6. Sort by the name of the item

# %%
#chipo.item_name.sort_values() #ชื่อDateFrame.colume name.sort_values()

# OR

chipo.sort_values(by = 'item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...                                                 ...         ...
# 2384  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 781   [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...        8.75
# 2851  [Roasted Chili Corn Salsa (Medium), [Black Bea...        8.49
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...        8.49
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 6. How many times was a Veggie Salad Bowl ordered?

# %%
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]
chipo_salad

len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ###Step 7. What was the quantity of the most expensive item ordered?

# %%
#teacher test
chipo.sort_values(by = 'item_price', ascending=False).head(1) #หา order ไหนที่แพงที่สุดแล้ว quantity ของ order นั้นเท่าไหร่

#toey test
#chipo.sort_values(by = ['quantity','item_price'], ascending=False).head(1) #quantity ที่มากที่สุด มีราคาเท่าไหร่
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 7. How many times did someone order more than one Canned Soda?

# %%
chipo_drink_steak_bowl = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
chipo_drink_steak_bowl
len(chipo_drink_steak_bowl)
# Out:
# 20

# %% [markdown]
# ###Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo_salad = chipo[chipo.item_name == 'Veggie Salad Bowl']
# info of chipo_salad is Veggie Salad Bowl
chipo_salad

# find times of chipo_salad is Veggie Salad Bowl
len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ### Step 8. How many products cost more than $10.00?

# %%
# clean the item_price column and transform it in a float
if chipo.item_price[0] == '$':
  prices = [float(value[1 : -1]) for value in chipo.item_price]

# reassign the column with the cleaned prices
chipo.item_price = prices

# delete the duplicates in item_name, quantity, and choice_description
chipo_filtered = chipo.drop_duplicates(['item_name','quantity','choice_description'])
print(chipo_filtered.shape)

# select only the products with quantity equals to 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
print(chipo_one_prod)

# chipo_one_prod[chipo_one_prod['item_price']>10].item_name.nunique()
# chipo_one_prod[chipo_one_prod['item_price']>10]

chipo.query('item_price > 10').item_name.nunique()
# Out:
# (1949, 5)
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4602      1827         1                       Barbacoa Burrito
# 4607      1829         1                          Steak Burrito
# 4610      1830         1                          Steak Burrito
# 4611      1830         1                         Veggie Burrito
# 4612      1831         1                          Carnitas Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# ...                                                 ...         ...
# 4602                      [Tomatillo Green Chili Salsa]        9.25
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...       11.75
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.25
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        9.25
#
# [1806 rows x 5 columns]
# 31

# %% [markdown]
# ###Step 9. How many times did someone order more than one Canned Soda?

# %%
# Find item_name is Canned Soda and Canned Soda that times(quantity) > 1
chipo_Canned_Soda = chipo[(chipo.item_name == 'Canned Soda') & (chipo.quantity > 1)]
# info of item_name is Canned Soda and Canned Soda that times(quantity) > 1
chipo_Canned_Soda

# find times of item_name is Canned Soda and Canned Soda that times(quantity) > 1
len(chipo_Canned_Soda)
# Out:
# 20

# %% [markdown]
# ### Step 9. What is the price of each item?

# %%
chipo[(chipo['item_name'] == 'Chicken Bowl') & (chipo['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# ...                                                 ...         ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
#
# [693 rows x 5 columns]
